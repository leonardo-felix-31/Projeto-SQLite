# %% [markdown]
# * Query 1
# ###### Cite as 5 pessoas colaboradoras que  tem as melhores remuneraçoes.

# %%
from IPython.display import Image
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-04-30 001116.png")

# %% [markdown]
# * Query  2
# ###### Qual o tempo médio de permanência dos colaboradores na empresa?

# %%
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-04-30 161700.png")

# %% [markdown]
# * Query 3
# ###### Qual a média de dependentes por colaborador?

# %%
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-04-30 165010.png")

# %% [markdown]
# * Query 4
# ###### Quantos dependentes estão em idade escolar (0–17 anos)?

# %%
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-04-30 165336.png")

# %% [markdown]
# * Query 5
# ###### Qual o custo médio de RH (salários, benefícios) por unidade de faturamento?

# %%
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-04-30 170330.png")

# %% [markdown]
# * Query 6
# ###### Qual a taxa de absenteísmo por área ?

# %%
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-04-30 172315.png")

# %% [markdown]
# * Query 7
# ###### Qual é a taxa de turnover por gestor (supervisor)

# %%
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-04-30 172355.png")
